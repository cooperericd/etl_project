# %%
import pandas as pd
from sqlalchemy import create_engine
import datetime as dt

# %%
airbnb_file = "AB_NYC_2019.csv"

# %%
airbnb_df = pd.read_csv(airbnb_file)
airbnb_df = airbnb_df.rename(columns={"host_id": "host_number", "host_name": "host_title",
                                      "neighbourhood_group":"borough"})

# %%
airbnb_df.head()
# Out:
#      id                                              name  host_number  \
# 0  2539                Clean & quiet apt home by the park         2787
# 1  2595                             Skylit Midtown Castle         2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !         4632
# 3  3831                   Cozy Entire Floor of Brownstone         4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park         7192
#
#     host_title    borough neighbourhood  latitude  longitude        room_type  \
# 0         John   Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1     Jennifer  Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2    Elisabeth  Manhattan        Harlem  40.80902  -73.94190     Private room
# 3  LisaRoxanne   Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4        Laura  Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
# 3     89               1                270  2019-07-05               4.64
# 4     80              10                  9  2018-11-19               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
# Create a filtered dataframe from specific columns
host_cols = ["host_number", "host_title"]
host= airbnb_df[host_cols].copy()
host= host.drop_duplicates()
host.set_index("host_number",inplace=True)

# %%
host.head()
# Out:
#               host_title
# host_number
# 2787                John
# 2845            Jennifer
# 4632           Elisabeth
# 4869         LisaRoxanne
# 7192               Laura

# %%
room_cols=["host_number", "room_type"]
room_type=airbnb_df[room_cols].copy()
room_type.drop_duplicates("room_type", inplace=True)

# %%
room_type=room_type.drop(columns=["host_number"])

# %%
room_type.index=range(1,4)
room_type=room_type.reset_index()
room_type=room_type.rename(columns={"index":"room_type_id"})
room_type
# Out:
#    room_type_id        room_type
# 0             1     Private room
# 1             2  Entire home/apt
# 2             3      Shared room

# %%
neighb_cols=["host_number","borough"]
neighb=airbnb_df[neighb_cols].copy()
neighb.drop_duplicates("borough",inplace=True)

# %%
neighb=neighb.drop(columns=["host_number"])

# %%
neighb.index=range(1,6)
neighb=neighb.reset_index()
neighbourhood_group_transformed=neighb.rename(columns={"index":"borough_id"})
neighbourhood_group_transformed
# Out:
#    borough_id        borough
# 0           1       Brooklyn
# 1           2      Manhattan
# 2           3         Queens
# 3           4  Staten Island
# 4           5          Bronx

# %%
neighb_join=pd.DataFrame.merge(airbnb_df,neighbourhood_group_transformed)

# %%
neighb_join.head(5)
# Out:
#      id                                            name  host_number  \
# 0  2539              Clean & quiet apt home by the park         2787
# 1  3831                 Cozy Entire Floor of Brownstone         4869
# 2  5121                                 BlissArtsSpace!         7356
# 3  5803  Lovely Room 1, Garden, Best Area, Legal rental         9744
# 4  6848                Only 2 stops to Manhattan studio        15991
#
#       host_title   borough       neighbourhood  latitude  longitude  \
# 0           John  Brooklyn          Kensington  40.64749  -73.97237
# 1    LisaRoxanne  Brooklyn        Clinton Hill  40.68514  -73.95976
# 2          Garon  Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3         Laurie  Brooklyn         South Slope  40.66829  -73.98779
# 4  Allen & Irina  Brooklyn        Williamsburg  40.70837  -73.95352
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt     89               1                270  2019-07-05
# 2     Private room     60              45                 49  2017-10-05
# 3     Private room     89               4                167  2019-06-24
# 4  Entire home/apt    140               2                148  2019-06-29
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.21                               6               365
# 1               4.64                               1               194
# 2               0.40                               1                 0
# 3               1.34                               3               314
# 4               1.20                               1                46
#
#    borough_id
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
neighbourhood_df =  neighb_join[["borough_id","neighbourhood"]]
neighbourhood_df = neighbourhood_df.dropna(how='any')
neighbourhood_df_unique = neighbourhood_df.drop_duplicates()
neighbourhood_df_unique.index=range(1,222)
neighbourhood_df_unique=neighbourhood_df_unique.reset_index()
neighbourhood=neighbourhood_df_unique.rename(columns={"index":"neighbourhood_id"})

neighbourhood.head(10)
# Out:
#    neighbourhood_id  borough_id       neighbourhood
# 0                 1           1          Kensington
# 1                 2           1        Clinton Hill
# 2                 3           1  Bedford-Stuyvesant
# 3                 4           1         South Slope
# 4                 5           1        Williamsburg
# 5                 6           1         Fort Greene
# 6                 7           1       Crown Heights
# 7                 8           1          Park Slope
# 8                 9           1     Windsor Terrace
# 9                10           1          Greenpoint

# %%
superJoin=pd.DataFrame.merge(neighb_join,neighbourhood)
superJoin["last_review"]=pd.to_datetime(superJoin["last_review"])

# %%
superJoin
# Out:
#              id                                               name  \
# 0          2539                 Clean & quiet apt home by the park
# 1         63546                     Large and Cozy Private Bedroom
# 2        125594                 SUPER BIG AND COZY PRIVATE BEDROOM
# 3        267652              Private clean pleasant spacious room.
# 4        282341                Kensington/Ditmas Park pied-a-terre
# 5        317905                Come and go as  you please in BKLN!
# 6        452068                 Spacious 4 bedroom house, New York
# 7        516791                                Lovely Brooklyn Apt
# 8        656281     QUIET, SPACIOUS, COMFORTABLE, & GREAT LOCATION
# 9        812467         Vintage Chic Haven in Kensington, Brooklyn
# 10       848170                    Gorgeous 1BR near Prospect Park
# 11       874706           Fully Updated Modern 1 Bedroom Apartment
# 12      1126944                Private Home w/ Parking in Brooklyn
# 13      1157036                     private spacious sunny bedroom
# 14      1239293                 Cozy Retreat in Brooklyn Apartment
# 15      1251681  Entire House in Brooklyn for 6, super good pri...
# 16      1305265                 Perfect House for the Whole Family
# 17      1351427                Charming New 3br House+bkyard BRKLN
# 18      2416104                Private home, quiet Brooklyn street
# 19      2736911                Full apt-Brooklyn-near park, SUNNY!
# 20      3039332                1910 Town House in leafy Kensington
# 21      3517646       Spacious, light-filled home by Prospect Park
# 22      3645866                              Welcome to Kensington
# 23      3688197                    Peaceful and breezy one bedroom
# 24      3692566                    Spacious 5 BR house in Brooklyn
# 25      3717749                         Two Porches & Private Room
# 26      3911632                       Cozy rooms with private bath
# 27      4129212        Large 1 Bedroom apartment with office room.
# 28      4500897                           Cozy Brooklyn Apartment!
# 29      4700809  Cozy Two-bedroom Apt in a Cute House in Brooklyn!
# ...         ...                                                ...
# 48865  17975664             Large, spacious, and comfortable house
# 48866  18078720                       Cozy one bedroom Street view
# 48867  21602731             Spacious 1 bedroom Apartment w/ 2 beds
# 48868  24601752                   Heaven in New York, Natural Room
# 48869  25354678                        Big Blue House in the Bronx
# 48870  25484515                           Your Home away from Home
# 48871  26777948                       Comfortable Studio Apartment
# 48866    124486054           Carlton     Bronx            Edenwald  40.88364
# 48867    138154835               Kay     Bronx            Edenwald  40.89215
# 48868    185908506           Cynthia     Bronx            Edenwald  40.88634
# 48869    107437866             Clint     Bronx            Edenwald  40.89124
# 48870    192335868           Johnnet     Bronx            Edenwald  40.89010
# 48871    120035273               Ral     Bronx            Edenwald  40.89245
# 48872    185908506           Cynthia     Bronx            Edenwald  40.88590
# 48873    217439132           Rosalyn     Bronx            Edenwald  40.88805
# 48874    185908506           Cynthia     Bronx            Edenwald  40.88500
# 48875    198442706             Marii     Bronx            Edenwald  40.88229
# 48876     98868828           Natasha     Bronx            Edenwald  40.89156
# 48877    138962369           Eugenia     Bronx            Edenwald  40.89039
# 48878       740812            Monica     Bronx  Westchester Square  40.83758
# 48879       740812            Monica     Bronx  Westchester Square  40.83720
# 48880    175152359           Massiel     Bronx  Westchester Square  40.84300
# 48881    175152359           Massiel     Bronx  Westchester Square  40.84367
# 48882     22125997        Lilly Rose     Bronx  Westchester Square  40.84184
# 48883    140862407           Angelie     Bronx  Westchester Square  40.84378
# 48884    243766178              Lola     Bronx  Westchester Square  40.83619
# 48885     22125997        Lilly Rose     Bronx  Westchester Square  40.84077
# 48886    126614438              Jada     Bronx  Westchester Square  40.83616
# 48887    270852954           Jasmine     Bronx  Westchester Square  40.83671
# 48888    129602851                W.     Bronx           Unionport  40.83121
# 48889    196468460  German And Wendy     Bronx           Unionport  40.82848
# 48890    208574990            Hattie     Bronx           Unionport  40.82972
# 48891     28960938            Vinroy     Bronx           Unionport  40.82598
# 48892    168891738  Miguel & Marisol     Bronx           Unionport  40.82661
# 48893    168891738  Miguel & Marisol     Bronx           Unionport  40.82670
# 48894    209915988            Ashley     Bronx           Unionport  40.82936
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.97426     Private room     39               1                 45
# 2      -73.97255     Private room     39               1                 82
# 3      -73.97296     Private room     60               2                 20
# 4      -73.97386  Entire home/apt     90              30                  3
# 5      -73.97777  Entire home/apt     89               3                 62
# 6      -73.97173  Entire home/apt    200               1                  3
# 7      -73.97932  Entire home/apt     90              10                 33
# 8      -73.98013     Private room     72               1                 48
# 9      -73.97417     Private room     49               1                 61
# 10     -73.97662  Entire home/apt    100               4                 20
# 11     -73.97189  Entire home/apt     95               3                154
# 12     -73.96976  Entire home/apt    300               5                  1
# 13     -73.97140     Private room     50              30                 10
# 14     -73.97860     Private room     75               2                  8
# 15     -73.97097  Entire home/apt    250               5                 11
# 16     -73.97851  Entire home/apt    299               3                  4
# 17     -73.97334  Entire home/apt    262              30                  1
# 18     -73.97559  Entire home/apt    200               2                 13
# 19     -73.97208  Entire home/apt    200               3                  2
# 20     -73.97723  Entire home/apt    499               7                  2
# 21     -73.97798  Entire home/apt    210               5                  3
# 22     -73.97556     Private room     49               2                  6
# 23     -73.97560  Entire home/apt     95               1                 10
# 24     -73.97632  Entire home/apt    395               3                 20
# 25     -73.98233     Private room     70               1                  2
# 26     -73.97895     Private room     65               1                 74
# 27     -73.97238     Private room     50               3                  8
# 28     -73.98182  Entire home/apt    115               7                  6
# 29     -73.97434     Private room     35               4                  0
# ...          ...              ...    ...             ...                ...
# 48865  -73.83434     Private room     75               1                 15
# 48866  -73.83561     Private room     70               3                  0
# 48867  -73.83351  Entire home/apt     75               3                 50
# 48868  -73.83431     Private room     75               3                 19
# 48869  -73.83423  Entire home/apt    149               2                 59
# 48870  -73.84031     Private room    125               1                 11
# 48871  -73.83721  Entire home/apt     42               1                 32
# 48872  -73.83517  Entire home/apt     95               3                  5
# 48873  -73.83248  Entire home/apt     90              15                  0
# 48874  -73.83518     Private room     75               3                  1
# 48875  -73.84295     Private room     80               1                  0
# 48876  -73.84197     Private room     65               1                  0
# 48877  -73.83186  Entire home/apt     50               3                  8
# 48878  -73.84382  Entire home/apt     72               2                 35
# 48879  -73.84345  Entire home/apt     70               2                 67
# 48880  -73.84806     Private room     65               2                  2
# 48881  -73.84911     Private room     65               2                 11
# 48882  -73.84967     Private room     28               1                 26
# 48883  -73.84469  Entire home/apt    670               1                  2
# 48884  -73.84916     Private room     52               4                  1
# 48885  -73.84870     Private room     50               3                  6
# 48886  -73.84638  Entire home/apt     75               1                  5
# 48887  -73.84677     Private room     75               1                  0
# 48888  -73.84830  Entire home/apt    450               2                  1
# 48889  -73.85466  Entire home/apt     85               2                 68
# 48890  -73.84957     Private room     60               1                  0
# 48891  -73.85203     Private room     90               7                  0
# 48892  -73.85710  Entire home/apt    100               2                 16
# 48893  -73.85704  Entire home/apt    100               2                 18
# 48894  -73.84854     Private room     75               1                  1
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-16               0.46                               2
# 2      2019-05-19               0.94                               2
# 3      2019-01-21               0.42                               1
# 4      2017-07-30               0.05                               1
# 5      2019-01-02               0.71                               1
# 6      2015-08-16               0.06                               1
# 7      2019-05-22               0.39                               1
# 8      2019-02-28               0.59                               1
# 9      2019-06-23               0.95                               1
# 10     2017-09-10               0.26                               1
# 11     2019-07-01               2.00                               1
# 12     2015-01-01               0.02                               1
# 13     2016-11-30               0.13                               1
# 14     2014-01-07               0.11                               1
# 15     2019-01-01               0.15                               1
# 16     2017-07-30               0.06                               1
# 17     2015-04-03               0.02                               1
# 18     2018-08-18               0.21                               2
# 19     2014-10-12               0.03                               1
# 20     2015-08-11               0.03                               1
# 21     2018-08-13               0.05                               1
# 22     2016-09-05               0.10                               1
# 23     2018-12-29               0.21                               1
# 24     2018-08-14               0.34                               1
# 25     2015-07-06               0.03                               1
# 26     2019-07-02               1.26                               2
# 27     2016-07-25               0.14                               2
# 28     2018-08-19               0.11                               1
# 29            NaT                NaN                               2
# ...           ...                ...                             ...
# 48865  2019-05-28               0.55                               1
# 48866         NaT                NaN                               1
# 48867  2019-06-17               3.02                               1
# 48868  2019-05-20               1.55                               3
# 48869  2019-06-24               4.33                               1
# 48870  2018-08-04               0.88                               1
# 48871  2019-06-20               2.74                               1
# 48872  2019-05-31               0.66                               3
# 48873         NaT                NaN                               1
# 48874  2018-11-20               0.13                               3
# 48875         NaT                NaN                               1
# 48876         NaT                NaN                               1
# 48877  2019-07-07               3.04                               1
# 48878  2019-06-23               1.52                               2
# 48879  2019-07-01               2.99                               2
# 48880  2019-06-23               0.13                               2
# 48881  2019-06-15               1.11                               2
# 48882  2019-06-21               2.65                               2
# 48883  2019-03-31               0.34                               1
# 48884  2019-02-22               0.22                               1
# 48885  2019-06-03               1.62                               2
# 48886  2019-06-24               3.95                               1
# 48887         NaT                NaN                               1
# 48888  2018-02-01               0.06                               2
# 48889  2019-07-04               5.37                               1
# 48890         NaT                NaN                               1
# 48891         NaT                NaN                               1
# 48892  2019-06-30               4.32                               2
# 48893  2019-06-28               4.78                               2
# 48894  2019-05-26               0.68                               1
#
#        availability_365  borough_id  neighbourhood_id
# 0                   365           1                 1
# 1                   365           1                 1
# 2                   365           1                 1
# 3                   347           1                 1
# 4                   286           1                 1
# 5                   189           1                 1
# 6                     0           1                 1
# 7                   269           1                 1
# 8                   312           1                 1
# 9                   100           1                 1
# 10                    0           1                 1
# 11                  310           1                 1
# 12                   15           1                 1
# 13                  205           1                 1
# 14                  312           1                 1
# 15                   34           1                 1
# 16                  321           1                 1
# 17                   16           1                 1
# 18                    0           1                 1
# 19                    0           1                 1
# 20                   31           1                 1
# 21                    0           1                 1
# 22                    0           1                 1
# 23                    0           1                 1
# 24                    9           1                 1
# 25                    0           1                 1
# 26                   21           1                 1
# 27                   14           1                 1
# 28                  183           1                 1
# 29                    0           1                 1
# ...                 ...         ...               ...
# 48865               348           5               219
# 48866               365           5               219
# 48867               148           5               219
# 48868               166           5               219
# 48869               328           5               219
# 48870               189           5               219
# 48871                32           5               219
# 48872               311           5               219
# 48873                89           5               219
# 48874               311           5               219
# 48875               365           5               219
# 48876                89           5               219
# 48877                34           5               219
# 48878               129           5               220
# 48879               129           5               220
# 48880               135           5               220
# 48881               158           5               220
# 48882               123           5               220
# 48883               178           5               220
# 48884                 0           5               220
# 48885                27           5               220
# 48886               355           5               220
# 48887               363           5               220
# 48888               342           5               221
# 48889               247           5               221
# 48890               268           5               221
# 48891               180           5               221
# 48892               161           5               221
# 48893               145           5               221
# 48894               365           5               221
#
# [48895 rows x 18 columns]

# %%
listing=pd.DataFrame.merge(superJoin,room_type)
listing=listing.drop(columns=["calculated_host_listings_count","borough_id","host_title","borough","neighbourhood","room_type"])
listing
# Out:
#              id                                               name  \
# 0          2539                 Clean & quiet apt home by the park
# 1         63546                     Large and Cozy Private Bedroom
# 2        125594                 SUPER BIG AND COZY PRIVATE BEDROOM
# 3        267652              Private clean pleasant spacious room.
# 4        656281     QUIET, SPACIOUS, COMFORTABLE, & GREAT LOCATION
# 5        812467         Vintage Chic Haven in Kensington, Brooklyn
# 6       1157036                     private spacious sunny bedroom
# 7       1239293                 Cozy Retreat in Brooklyn Apartment
# 8       3645866                              Welcome to Kensington
# 9       3717749                         Two Porches & Private Room
# 10      3911632                       Cozy rooms with private bath
# 11      4129212        Large 1 Bedroom apartment with office room.
# 12      4700809  Cozy Two-bedroom Apt in a Cute House in Brooklyn!
# 13      4823959                  Private room for 2 in cool BK apt
# 14      5079124                          Clean & Cozy Private Room
# 15      5523413                                Oasis in Kensington
# 16      5717674                               Welcome to Brooklyn!
# 17      5771655                       Brooklyn Bargain for August!
# 18      6305553                        BK Room Available 5/17-5/24
# 19      6344926                              Brooklyn private room
# 20      6749837    2 beds in 3 bed with balcony in elevator bldng!
# 21      7306096                           Big, nice, private room.
# 22      7835778                 Bright room in quiet Brooklyn home
# 23      8130534                  Lovely BR w/Access to Everything!
# 24      8250280                                Zee's Brooklyn nest
# 25      9107681   A Dreamy Brooklyn Solarium nearby Prospect Park!
# 26      9768765                        Room in quiet Brooklyn home
# 27     11096888                    Peaceful apartment close to F/G
# 28     11549676                   Spacious Room w private bathroom
# 29     11707920                 Brooklyn private bath by F,G train
# ...         ...                                                ...
# 48865  12933540       Comfortable Sofa bed 15 minutes to Manhattan
# 48866  19974905                                     Esteem's Place
# 48867  27703561      both world getting to the city and safe place
# 48868  29906233                             BRONX SUNNY CLEAN ROOM
# 48869  34659522   Private area  for comfortable and pleasant stay.
# 48870  35232958  Coziest & magical beds behind living room curt...
# 48871  35546298  ★Official & Only 6★Star Airbnb w/ TempurPedic Bed
# 48872  20330081         New York's Hidden Secret for luxury living
# 48873  25618799      Shared space w/privacy near NY Botanic Garden
# 48874   2772111                       It's very warm and friendly.
# 48875  12988898                                                NaN
# 48876  28369910                               Semi Private Bedroom
# 48877  35069663                        Apartamento compartido NYC.
# 48878  30942778  Share a Lg Studio room* 2 blocks subway* Bronx...
# 48879  31032487   Share Lg studio rm b2*2 blocks subway *Bronx Zoo
# 48880  31053045      Sleeper shared rm on subway bronx zoo 30m2NYC
# 48881  28810799  Spacious Comfy livingroom Lounge spot in Bronx...
# 48882  32263166                       Welcome to my Lovely Studio.
# 48883  33422954                                    Spacious Studio
# 48884   8324941                          Charming studio apartment
# 48885  36379669                  Shared living space in the Bronx!
# 48886  32896994                                            X Night
# 48887  33987446                                            X Light
# 48888  34851748                                                  X
# 48889  34229869                             Cozy Living Room Futon
# 48890  19823964                                                 Fm
# 48891  33995462   Bronx, Little Italy, Arthur Ave, Fordham, Yanks.
# 48892  17475107     Partitioned (shared) Cozy Studio in Pelham Bay
# 48893  23670513                         Nice place for ladies only
# 48894  36199363    Furnished room  for rent in Bronx SINGLE FEMALE
#
#        host_number  latitude  longitude  price  minimum_nights  \
# 0             2787  40.64749  -73.97237    149               1
# 1           308652  40.64106  -73.97426     39               1
# 2           308652  40.64302  -73.97255     39               1
# 3           164675  40.64277  -73.97296     60               2
# 4          3180741  40.64573  -73.98013     72               1
# 5           574584  40.63547  -73.97417     49               1
# 6          3696460  40.63381  -73.97140     50              30
# 7          6755111  40.64120  -73.97860     75               2
# 8           946672  40.63402  -73.97556     49               2
# 9          5573250  40.64130  -73.98233     70               1
# 13                     0         NaT                NaN                 0
# 14                    39  2019-06-24               0.77               245
# 15                     8  2019-05-18               0.15                27
# 16                     8  2016-10-18               0.17                 0
# 17                     1  2015-06-19               0.02                 1
# 18                     0         NaT                NaN                 0
# 19                    43  2019-01-08               0.87                99
# 20                     0         NaT                NaN                 0
# 21                     5  2015-09-15               0.10                 0
# 22                     1  2015-08-31               0.02                 0
# 23                     1  2015-11-05               0.02                 0
# 24                     7  2019-07-03               2.63                37
# 25                     1  2016-01-02               0.02                 0
# 26                     1  2016-01-29               0.02                 0
# 27                     0         NaT                NaN               358
# 28                     2  2018-04-30               0.06                 0
# 29                   108  2019-06-19               2.68                23
# ...                  ...         ...                ...               ...
# 48865                  9  2017-05-20               0.26                89
# 48866                 18  2019-04-23               0.78               342
# 48867                  4  2018-11-25               0.39                 0
# 48868                  0         NaT                NaN               280
# 48869                  0         NaT                NaN                71
# 48870                  0         NaT                NaN               364
# 48871                  4  2019-06-30               4.00               340
# 48872                  1  2017-09-03               0.04               269
# 48873                  8  2019-05-19               0.71                 6
# 48874                 10  2018-10-13               0.16               365
# 48875                  0         NaT                NaN               365
# 48876                  3  2019-02-23               0.31                83
# 48877                  1  2019-06-03               0.83                11
# 48878                  1  2019-05-08               0.48               139
# 48879                  2  2019-06-30               0.32               114
# 48880                  3  2019-07-01               0.68                25
# 48881                  2  2018-10-29               0.23                88
# 48882                  7  2019-05-19               1.54               158
# 48883                  5  2019-07-01               1.60               146
# 48884                  0         NaT                NaN               364
# 48885                  0         NaT                NaN                88
# 48886                  0         NaT                NaN                90
# 48887                  0         NaT                NaN               179
# 48888                  0         NaT                NaN               365
# 48889                  0         NaT                NaN                 5
# 48890                  0         NaT                NaN                 0
# 48891                  2  2019-06-03               0.94               358
# 48892                116  2019-01-28               4.09                 5
# 48893                 10  2019-03-07               0.67               312
# 48894                  0         NaT                NaN               190
#
#        neighbourhood_id  room_type_id
# 0                     1             1
# 1                     1             1
# 2                     1             1
# 3                     1             1
# 4                     1             1
# 5                     1             1
# 6                     1             1
# 7                     1             1
# 8                     1             1
# 9                     1             1
# 10                    1             1
# 11                    1             1
# 12                    1             1
# 13                    1             1
# 14                    1             1
# 15                    1             1
# 16                    1             1
# 17                    1             1
# 18                    1             1
# 19                    1             1
# 20                    1             1
# 21                    1             1
# 22                    1             1
# 23                    1             1
# 24                    1             1
# 25                    1             1
# 26                    1             1
# 27                    1             1
# 28                    1             1
# 29                    1             1
# ...                 ...           ...
# 48865               195             3
# 48866               195             3
# 48867               195             3
# 48868               195             3
# 48869               195             3
# 48870               195             3
# 48871               197             3
# 48872               198             3
# 48873               199             3
# 48874               201             3
# 48875               201             3
# 48876               201             3
# 48877               201             3
# 48878               203             3
# 48879               203             3
# 48880               203             3
# 48881               204             3
# 48882               205             3
# 48883               205             3
# 48884               208             3
# 48885               208             3
# 48886               211             3
# 48887               211             3
# 48888               211             3
# 48889               212             3
# 48890               213             3
# 48891               213             3
# 48892               216             3
# 48893               218             3
# 48894               218             3
#
# [48895 rows x 13 columns]

# %%
pw = input("Password: ")
connection_string = "postgres:" + str(pw) + "@localhost:5432/airbnb_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['borough', 'neighbourhood', 'listing', 'room_type', 'host']

# %%
host.to_sql(name='host', con=engine, if_exists='append', index=True)

# %%
neighbourhood_group_transformed.to_sql(name='borough', con=engine, if_exists='append', index=False)

# %%
neighbourhood.to_sql(name='neighbourhood', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#
# UniqueViolation: duplicate key value violates unique constraint "neighbourhood_pkey"
# DETAIL:  Key (neighbourhood_id)=(1) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-29-6298c315261d> in <module>
# ----> 1 neighbourhood.to_sql(name='neighbourhood', con=engine, if_exists='append', index=False)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1172                          schema=schema, dtype=dtype)
#    1173         table.create()
# -> 1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#    1176             # check for potentially case sensitivity issues (GH7815)
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     684
#     685                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 686                 exec_insert(conn, keys, chunk_iter)
#     687
#     688     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     597         """
#     598         data = [dict(zip(keys, row)) for row in data_iter]
# --> 599         conn.execute(self.table.insert(), data)
#     600
#     601     def _execute_insert_multi(self, conn, keys, data_iter):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     723             extras.execute_batch(cursor, statement, parameters)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#     727     @util.memoized_instancemethod
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "neighbourhood_pkey"
# DETAIL:  Key (neighbourhood_id)=(1) already exists.
#
# [SQL: INSERT INTO neighbourhood (neighbourhood_id, borough_id, neighbourhood) VALUES (%(neighbourhood_id)s, %(borough_id)s, %(neighbourhood)s)]
# [parameters: ({'neighbourhood_id': 1, 'borough_id': 1, 'neighbourhood': 'Kensington'}, {'neighbourhood_id': 2, 'borough_id': 1, 'neighbourhood': 'Clinton Hill'}, {'neighbourhood_id': 3, 'borough_id': 1, 'neighbourhood': 'Bedford-Stuyvesant'}, {'neighbourhood_id': 4, 'borough_id': 1, 'neighbourhood': 'South Slope'}, {'neighbourhood_id': 5, 'borough_id': 1, 'neighbourhood': 'Williamsburg'}, {'neighbourhood_id': 6, 'borough_id': 1, 'neighbourhood': 'Fort Greene'}, {'neighbourhood_id': 7, 'borough_id': 1, 'neighbourhood': 'Crown Heights'}, {'neighbourhood_id': 8, 'borough_id': 1, 'neighbourhood': 'Park Slope'}  ... displaying 10 of 221 total bound parameter sets ...  {'neighbourhood_id': 220, 'borough_id': 5, 'neighbourhood': 'Westchester Square'}, {'neighbourhood_id': 221, 'borough_id': 5, 'neighbourhood': 'Unionport'})]
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
room_type.to_sql(name='room_type', con=engine, if_exists='append', index=False)

# %%
listing.to_sql(name='listing', con=engine, if_exists='append', index=False)
